# %% [markdown]
# <h1>Задание к уроку 5:</h1> <h3>"Проверка статистических гипотез. P-значения. Доверительные интервалы. A/B-тестирование"</h3>

# %% [markdown]
# __1) Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16. Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95, если выборочная средняя M = 80, а объем выборки n = 256.__

# %% [markdown]
# $$ \sigma=16;\,\, 1-\alpha=0.95\%;\,\, \alpha = 5\%;\,\, \mu = 80;\,\, n=256 $$
#
# $$ \overline{X} \pm Z_{\frac{\alpha}{2}}\cdot\frac{\sigma}{\sqrt{n}} = 80 \pm 1.96 \cdot \frac{16}{16} = 80 \pm 1.96$$
#
# Доверительный интервал равен: $[78.04;\,\, 81.96]$

# %% [markdown]
# __2) В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью,
# получены опытные данные:
# 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
# Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей,
# оценить истинное значение величины X при помощи доверительного интервала, покрывающего это
# значение с доверительной вероятностью 0,95.__

# %% [markdown]
# $$ n = 10;\,\, 1-\alpha = 95\%;\,\, \alpha = 5\%;$$
#
# $$ \mu = \frac{6.9+6.1+6.2+6.8+7.5+6.3+6.4+6.9+6.7+6.1}{10} = \frac{65.9}{10} = 6.59 $$
#
# $$ \sigma = \sqrt{\frac{\sum_{i=1}^{n} (x_{i}-\overline{x})^{2}}{n-1}} = \sqrt{\frac{1.829}{9}} = \sqrt{0.203} = 0.45 $$
#
# $$ \mu \pm t_{\frac{\alpha}{2}} \cdot \frac{\sigma}{\sqrt{n}} = 6.59 \pm 2.262 \cdot \frac{0.45} = {\sqrt{10}} = 6.59 \pm 0.322$$
#
# Доверительный интервал равет: $[6.268;\,\,6.912]$

# %% [markdown]
# __3) Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр
# оказался равным 17.5 мм, а дисперсия известна и равна 4 кв.мм.__

# %% [markdown]
# $$ \mu_{0} = 17mm;\,\, \alpha = 5\%;\,\, n=100;\,\, \mu_{1} = 17.5mm;\,\, D = 4mm^{2}$$

# %% [markdown]
# $$ \sigma = \sqrt{D} = \sqrt{4} = 2 $$

# %% [markdown]
# $$ Z_{T} = 1.65$$
#
# $$ Z_{R} = \frac{\mu_{1}-\mu_{0}}{\frac{\sigma}{\sqrt{n}}} = \frac{17.5 - 17}{\frac{2}{\sqrt{100}}} = \frac{0.5}{0.2} = 2.5$$

# %% [markdown]
# Так как $\,\,Z_{T}<Z_{R}\,\,$ следует, что верна альтернативная гепотиза на уровне значимости $5\%$.

# %% [markdown]
# __4) Продавец утверждает, что средний вес пачки печенья составляет 200 г.
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально.
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?__

# %% [markdown]
# $$ \mu_{0} = 200;\,\, n=10;\,\, 1-\alpha = 99\%;\,\, \alpha = 1\%$$
#
# $$ \mu = \frac{\sum_{i=1}^{n}{x_{i}}}{n} = \frac{1985}{10} = 198.5 $$
#
# $$ \sigma = \sqrt{\frac{\sum_{i=1}^{n}(x_{i}-\overline{x})^2}{n-1}} = \sqrt{\frac{178.5}{9}} = \sqrt{19.83} = 4.45 $$
#
# $$ t_{T} =  \pm 3.25 $$
#
# $$ t_{P} = \frac{\mu - \mu_{0}} {\frac{\sigma}{\sqrt{n}}} = \frac{198.5 - 200}{\frac{4.45}{\sqrt{10}}} = - 1.065 $$
#
# Так как $\,\,t_{P} = -1.065\,\,$ лежит в интервале $\,\,t_{T} = [-3.25; 3.25],\,\,$ верна нулевая гипотеза на уровне значимости $1\%$
