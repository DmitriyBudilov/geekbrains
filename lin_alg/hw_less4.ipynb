# %% [markdown]
# ### Практическое задание к уроку 4 "Системы линейных уравнений".

# %% [markdown]
# ###  Часть 1

# %% [markdown]
# __1.__ Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$

# %% [markdown]
# $$
# A=\begin{pmatrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1\\
# 1 & 1 & -3 & 1
# \end{pmatrix};
# \tilde{A}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1\\
# 1 & 1 & -3 & 1
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -2 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 0 & 0 & 3\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -2 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# -2\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}
# $$
#
# $$
# \begin{cases}
# x_1 + 3x_4 = -2\\
# -x_2 + x_3 + 5x_4 = -2\\
# -2x_3 + 3X_4 = 4
# \end{cases}
# $$
#
# Данная система является совместной и неопределённой. Её общее решение является:
#
# $$
# x_3 = \frac{4 - 3x_4}{-2} = 1.5x_4 - 2
# $$
#
# $$
# x_2 = 2 + x_3 + 5x_4 = 2 + 1.5x_4 - 2 + 5x_4 = 6.5x_4
# $$
#
# $$
# x_1 = -2 - 3x_4
# $$
#
# Одно из частных решений при $x_4 = 0$ является:
# $x_1 = -2$; $x_2 = 0$; $x_3 = -2$

# %% [markdown]
# __2.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:

# %% [markdown]
#    а) $$\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$$
#
# $$
# \tilde A=
# \begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 2 & -5 & -3\\
# 1 & 1 & -1
# \end{matrix}
# \right |
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 2 & -5 & -3\\
# 3 & -1 & 1
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# -17\\
# 4
# \end{matrix}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 2 & -5 & -3\\
# 1 & 4 & 2
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# -17\\
# 21
# \end{matrix}
# \end{pmatrix}
# =
# $$
#
# $$
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & -7 & -1\\
# 0 & 3 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# -17\\
# 21
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & -1 & 5\\
# 0 & 3 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# 25\\
# 21
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & -1 & 5\\
# 0 & 0 & 18
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# 25\\
# 96
# \end{matrix}
# \end{pmatrix}
# $$
#
# $$
# =
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1\\
# 0 & -1 & 5\\
# 0 & 0 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 0\\
# 25\\
# 16
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 0 & 4\\
# 0 & -1 & 5\\
# 0 & 0 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 25\\
# 25\\
# 16
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 0 & 1\\
# 0 & -1 & 2\\
# 0 & 0 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 9\\
# 9\\
# 16
# \end{matrix}
# \end{pmatrix}
# $$
#
# $$
# \begin{cases}
# x_1 + x_3 = 9\\
# -x_2 + 2x_3 = 9\\
# 3x_3 = 16
# \end{cases}
# $$
#
# $$
# x_3 = \frac{16}{3}
# $$
# $$
# x_2=2x_3-9=\frac{32}{3} - \frac{27}{3}=\frac{5}{3}
# $$
#
# $$
# x_1=9-\frac{16}{3}=\frac{27}{3} - \frac{16}{3}=\frac{11}{3}
# $$
# __система совместна и определена__

# %% [markdown]
#    б) $$\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$$

# %% [markdown]
# $$
# A=
# \begin{pmatrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 3 & -6 & 9
# \end{pmatrix};
# \tilde A=
# \begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 3 & -6 & 9
# \end{matrix}
# \right |
# \begin{matrix}
# 1\\
# -1\\
# 5
# \end{matrix}
# \end{pmatrix}
# $$
#
# $$
# rang\tilde A=
# \begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 3 & -6 & 9
# \end{matrix}
# \right |
# \begin{matrix}
# 1\\
# -1\\
# 5
# \end{matrix}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 1 & -2 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# 1\\
# -1\\
# 4
# \end{matrix}
# \end{pmatrix}
# =
# \begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 0 & 0 & 0
# \end{matrix}
# \right |
# \begin{matrix}
# 1\\
# -1\\
# 5
# \end{matrix}
# \end{pmatrix}
# $$
#
# Третья строка расширенной матрицы имеет вид $0\cdot x_1 + 0\cdot x_2 + 0\cdot x_3 = 5$, следовательно __система несовместна__.

# %% [markdown]
#    в) $$\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$$
#
# $$
# A=
# \begin{pmatrix}
# 1 & 2 & 5\\
# 3 & 1 & -8
# \end{pmatrix}=
# \begin{pmatrix}
# 1 & 2 & 5\\
# 3 & 1 & -8
# \end{pmatrix}
# ;
# \tilde A=
# \begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5\\
# 0 & -5 & -23
# \end{matrix}
# \right|
# \begin{matrix}
# 4\\
# -14
# \end{matrix}
# \end{pmatrix}
# $$
#
# $$rangA = rang \tilde A$$
# __Система совместна и неопределена__

# %% [markdown]
# __3.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
# $$rang A = 3, rang \tilde A = 3$$
# так как ранг матрицы равен рангу расширенной матрицы следовательно __система совместна и определена__.

# %% [markdown]
# __4.__ Дана система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$$
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.

# %% [markdown]
# $$
# \tilde A=
# \begin{pmatrix}
# \left.
# \begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}
# \right |
# \begin{matrix}
# a\\
# b\\
# c\\
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.
# \begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 3 & 3 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# a\\
# b\\
# c-b\\
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.
# \begin{matrix}
# 1 & 2 & 3\\
# 1 & 2 & 3\\
# 3 & 3 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# a\\
# 2b-c\\
# c-b\\
# \end{matrix}
# \end{pmatrix}=
# \begin{pmatrix}
# \left.
# \begin{matrix}
# 0 & 0 & 0\\
# 1 & 2 & 3\\
# 3 & 3 & 3
# \end{matrix}
# \right |
# \begin{matrix}
# a-2b+c\\
# 2b-c\\
# c-b\\
# \end{matrix}
# \end{pmatrix}
# $$
#
# В случае, когда $a - 2b +c \neq 0 $ __система несовместна__

# %% [markdown]
# ### Часть 2

# %% [markdown]
# __1.__ Решить систему уравнений методом Крамера:

# %% [markdown]
# а) $$\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$$

# %% [markdown]
# $$
# detA =
# \begin{vmatrix}
# 1 & -2\\
# 3 & -4
# \end{vmatrix}
# =
# -4 + 6 = 2
# $$
#
# Так как $detA \neq 0$ __система совместна__.
#
# $$
# detA_1 =
# \begin{vmatrix}
# 1 & -2\\
# 7 & -4
# \end{vmatrix}
# =
# -4 + 14 = 10;
# $$
#
# $$
# detA_2 =
# \begin{vmatrix}
# 1 & 1\\
# 3 & 7
# \end{vmatrix}
# =
# 7 - 3 = 4
# $$
#
# Таким образом:
# $$
# x_1 = \frac{detA_1}{detA} = \frac{10}{2} = 5
# $$
#
# $$
# x_2 = \frac{detA_2}{detA} = \frac{4}{2} = 2
# $$

# %% [markdown]
#    б) $$\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$$

# %% [markdown]
# $$
# detA =
# \begin{vmatrix}
# 2 & -1 & 5\\
# 1 & 1 & -3\\
# 2 & 4 & 1
# \end{vmatrix}
# = (2 + 6 +20) - (10 - 24 - 1) = 43
# $$
#
# Так как $detA \neq 0$ __система совместна__.
#
# $$
# detA_1 =
# \begin{vmatrix}
# 10 & -1 & 5\\
# -2 & 1& -3\\
# 1 & 4 & 1
# \end{vmatrix}
# = (10 + 3 -40) - (5 - 120 +2) = 86;
# $$
#
# $$
# detA_2 =
# \begin{vmatrix}
# 2 & 10 & 5\\
# 1 & -2 & -3\\
# 2 & 1 & 1
# \end{vmatrix}
# = (-4 -60 +5) - (-20 +10 -6) = -43
# $$
#
# $$
# detA_3 =
# \begin{vmatrix}
# 2 & -1 & 10\\
# 1 & 1 & -2\\
# 2 & 4 & 1
# \end{vmatrix}
# = (2 + 4 + 40) - (20 -16 -1) = 43
# $$
#
# Таким образом:
# $$
# x_1 = \frac{detA_1}{detA} = \frac{86}{43} = 2
# $$
#
# $$
# x_2 = \frac{detA_2}{detA} = -\frac{43}{43} = -1
# $$
#
# $$
# x_3 = \frac{detA_3}{detA} = \frac{43}{43} =1
# $$
